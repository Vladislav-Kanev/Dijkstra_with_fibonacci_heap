# %% [markdown]
# Задача о кратчайших путях: алг. Дейкстры с метками и на  фибоначчиевой куче***+

# %%
import pandas as pd
import time

from src.Dijkstra import  dijkstra_with_labels, dijkstra_fibonacci_heap
from src.Graph import generate_graph
from src.Statistic import collect_statistics, plot_results

# %%
labels_result, heap_result = collect_statistics(100, 1000, 100, 10)
plot_results(labels_result, heap_result)

# %%
labels_result, heap_result = collect_statistics(500, 5000, 500, 10)
plot_results(labels_result, heap_result)
